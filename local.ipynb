# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/tanakatooryu/dsp2final/tanakatorudsp/macq.csv")
df
# Out:
#               timestamp university_answer windows_experience  \
# 0   2024/01/10 21:33:28               Yes                 最悪
# 1   2024/01/10 23:47:58               Yes                 最悪
# 2    2024/01/11 0:07:19               Yes              最高に良い
# 3    2024/01/11 0:07:38               Yes                 良い
# 4    2024/01/11 0:07:51               Yes                 良い
# 5    2024/01/11 0:08:27               Yes                 良い
# 6    2024/01/11 0:08:48               Yes                 良い
# 7    2024/01/11 0:09:02               Yes                 良い
# 8    2024/01/11 0:11:01               Yes                 良い
# 9    2024/01/11 0:13:47               Yes                 良い
# 10   2024/01/11 0:15:29               Yes                 普通
# 11   2024/01/11 0:21:12               Yes                 良い
# 12   2024/01/11 0:39:25               Yes                 良い
# 13   2024/01/11 0:49:41               Yes              最高に良い
# ...

# %%
db_name = "macq.db"
conn = sqlite3.connect(db_name)

# %%
conn

# %%
df.to_sql("mac_class", conn, if_exists="replace")
# Out:
# 29

# %%
c = conn.cursor()

# %%
query = 'SELECT * FROM mac_class'
c.execute (query)

# %%
for row in c.execute(query):
  print(row)
# Out:
# (0, '2024/01/10 21:33:28', 'Yes', '最悪', '対応しているアプリケーションが少ない(自分の使用したいアプリが対応していない)')
# (1, '2024/01/10 23:47:58', 'Yes', '最悪', 'プログラミング学習に向いていないから')
# (2, '2024/01/11 0:07:19', 'Yes', '最高に良い', '学校の指定でないから')
# (3, '2024/01/11 0:07:38', 'Yes', '良い', '学校の指定でないから')
# (4, '2024/01/11 0:07:51', 'Yes', '良い', 'プログラミング学習に向いていないから')
# (5, '2024/01/11 0:08:27', 'Yes', '良い', '学校の指定でないから')
# (6, '2024/01/11 0:08:48', 'Yes', '良い', '学校の指定でないから')
# (7, '2024/01/11 0:09:02', 'Yes', '良い', '学校の指定でないから')
# (8, '2024/01/11 0:11:01', 'Yes', '良い', '学校の指定でないから')
# (9, '2024/01/11 0:13:47', 'Yes', '良い', '学校の指定でないから')
# (10, '2024/01/11 0:15:29', 'Yes', '普通', '学校の指定でないから')
# (11, '2024/01/11 0:21:12', 'Yes', '良い', '先輩がPCのことに詳しくないならMacにしておいたほうが良いと言っていたから')
# (12, '2024/01/11 0:39:25', 'Yes', '良い', '学校の指定でないから')
# (13, '2024/01/11 0:49:41', 'Yes', '最高に良い', '対応しているアプリケーションが少ない(自分の使用したいアプリが対応していない)')
# (14, '2024/01/11 1:22:02', 'Yes', '最高に良い', 'プログラミング学習に向いていないから')
# ...

# %%
db_path = '/Users/tanakatooryu/dsp2final/tanakatorudsp/macq.db'
conn = sqlite3.connect(db_path)


cursor = conn.cursor()

query = "SELECT reason_for_not_choosing_win FROM mac_class"
cursor.execute(query)
data = cursor.fetchall()

conn.close()

reasons = [item[0] for item in data]

reason_counts = dict()
for reason in reasons:
    reason_counts[reason] = reason_counts.get(reason, 0) + 1

labels = list(reason_counts.keys())
sizes = list(reason_counts.values())


plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Reasons for not choosing win')
plt.show()

# %%
db_path = '/Users/tanakatooryu/dsp2final/tanakatorudsp/macq.db'
conn = sqlite3.connect(db_path)


cursor = conn.cursor()

query = "SELECT windows_experience FROM mac_class"
cursor.execute(query)
data = cursor.fetchall()

conn.close()

reasons = [item[0] for item in data]

reason_counts = dict()
for reason in reasons:
    reason_counts[reason] = reason_counts.get(reason, 0) + 1

labels = list(reason_counts.keys())
sizes = list(reason_counts.values())


plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('windows_experience')
plt.show()
# Out:
# /Users/tanakatooryu/.pyenv/versions/3.9.10/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26368 (\N{CJK UNIFIED IDEOGRAPH-6700}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/tanakatooryu/.pyenv/versions/3.9.10/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24746 (\N{CJK UNIFIED IDEOGRAPH-60AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/tanakatooryu/.pyenv/versions/3.9.10/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/tanakatooryu/.pyenv/versions/3.9.10/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26222 (\N{CJK UNIFIED IDEOGRAPH-666E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
